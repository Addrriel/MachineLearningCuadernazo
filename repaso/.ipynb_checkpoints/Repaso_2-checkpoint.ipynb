# %%
"""
SECCIÓN 1:

1) Pide un número y una palabra, muestra la concatenación.

2) Concatena un número flotante con un string sin usar str().

3) Recibe dos números y una palabra, concatena el mayor con la palabra.

4) Concatena solo si el número es positivo.

5) Muestra el resultado en mayúsculas.

"""

#1) EJERCICIO 1

#LÓGICA

#1. Crear una variable de tipo int
#2. Crear una variable de tipo string
#3. Crear una variable llamada "juntar_variable" transformando el string de entero a cadena de texto
#4. Print

"""
numero_ejercicio1 = int(input("Coloque su edad: "))
string_ejercicio1 = input("Coloque una frase que le guste")
juntar_variable = string_ejercicio1 + str(numero_ejercicio1)
#print(juntar_variable) ##le quito para que no moleste
print()

le hago comentario para que no moleste mientras hago los demás xd
"""

#2) EJERCICIO 2

#LÓGICA

#1. Crear una variable flotante
#2. Crear una variable string
#3. Transformar el string a flotante
#4. print

numero_ejercicio2 = 4.12
string_ejercicio2 = "12.25"
variable_total = float(string_ejercicio2) + numero_ejercicio2
print(variable_total)

#3) EJERCICIO 3

#LÓGICA

#Recibe dos números y una palabra, concatena el mayor con la palabra.
#1) Crear dos variables numéricas
#2) Crear una variable tipo string
#3) Crear un if en el cual el mayor tendrá el print para concatenar
#4) Transformar a string el número
#5) Print

numero_ejercicio3_1 = 12
numero_ejercicio3_2 = 24
string_ejercicio3 = " años de edad"

if numero_ejercicio3_1 >= numero_ejercicio3_2:
    variable_general = str(numero_ejercicio3_1) + string_ejercicio3
    print(variable_general)
else:
    variable_general = str(numero_ejercicio3_2) + string_ejercicio3
    print(variable_general)
# Out:
# 16.37
# 24 años de edad

# %%
"""
SECCIÓN 2:

Verifica si N pertenece a [5, 20).

El usuario ingresa N, a y b. Muestra True o False.

Cuenta cuántos valores entre 1 y 50 están en [10, 30).

Verifica el intervalo con números negativos.

Pide 5 números y muestra cuántos están en [0, 100).
"""

# %%
"""
SECCIÓN 3:

Comprueba si el substring S1[2:6] está en S2.

Permite que el usuario indique N1 y N2.

Ignora mayúsculas y minúsculas.

Muestra el substring extraído.

Cuenta cuántas veces aparece el substring en S2.
"""

# %%
"""
SECCIÓN 4:

Elimina duplicados de [1,1,2,3,3,4,5,5].

Hazlo sin usar set.

Mantén el orden original.

Cuenta cuántos elementos únicos quedan.

Elimina duplicados de una lista ingresada por el usuario.
"""

# %%
"""
SECCIÓN 5: 

Reemplaza "rojo" por "azul" en una lista de colores.

Reemplaza todos los valores "0" por "cero".

Reemplaza solo la primera ocurrencia.

El usuario ingresa la palabra a cambiar.

Muestra cuántos cambios se hicieron.
"""

# %%
"""
SECCIÓN 6:

Cambia el último valor de (5,10,15,20).

Reemplaza el primer valor.

Suma 10 al último elemento.

Intercambia el primer y último elemento.

Crea una nueva tupla solo con los pares.
"""

# %%
"""
SECCIÓN 7:

Desde [2,4,6,8,10] obtén [10,6,2].

Obtén solo los impares en orden inverso.

Extrae los números mayores a 5 y multiplícalos por 2.

Crea una lista con los múltiplos de 3 en orden descendente.

Elimina los números menores a 4.
"""

# %%
"""
SECCIÓN 8:

Elimina el índice 2 de (1,2,3,4,5).

El usuario ingresa el índice.

Elimina el último elemento.

Elimina el primer elemento.

Elimina un índice aleatorio usando random.
"""

"""
SECCIÓN 9:

"""
